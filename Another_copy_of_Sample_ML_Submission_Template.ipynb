# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilmishra-tech/The-Fair-Affairs-Analytical-Study/blob/main/Another_copy_of_Sample_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Affairs.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    Unnamed: 0  rate_marriage   age  yrs_married  children  religious  educ  \
# 0           0            3.0  32.0          9.0       3.0        3.0  17.0
# 1           1            3.0  27.0         13.0       3.0        1.0  14.0
# 2           2            4.0  22.0          2.5       0.0        1.0  16.0
# 3           3            4.0  37.0         16.5       4.0        3.0  16.0
# 4           4            5.0  27.0          9.0       1.0        1.0  14.0
#
#    occupation  occupation_husb   affairs
# 0         2.0              5.0  0.111111
# 1         3.0              4.0  3.230769
# 2         3.0              5.0  1.400000
# 3         5.0              5.0  0.727273
# 4         3.0              4.0  4.666666

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (6366, 10)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6366 entries, 0 to 6365
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6366 non-null   int64
#  1   rate_marriage    6366 non-null   float64
#  2   age              6366 non-null   float64
#  3   yrs_married      6366 non-null   float64
#  4   children         6366 non-null   float64
#  5   religious        6366 non-null   float64
#  6   educ             6366 non-null   float64
#  7   occupation       6366 non-null   float64
#  8   occupation_husb  6366 non-null   float64
#  9   affairs          6366 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 497.5 KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Unnamed: 0         0
# rate_marriage      0
# age                0
# yrs_married        0
# children           0
# religious          0
# educ               0
# occupation         0
# occupation_husb    0
# affairs            0
# dtype: int64

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.shape[1]
# Out:
# 10

# %%
# Dataset Describe
df.describe()
# Out:
#         Unnamed: 0  rate_marriage          age  yrs_married     children  \
# count  6366.000000    6366.000000  6366.000000  6366.000000  6366.000000
# mean   3182.500000       4.109645    29.082862     9.009425     1.396874
# std    1837.850239       0.961430     6.847882     7.280120     1.433471
# min       0.000000       1.000000    17.500000     0.500000     0.000000
# 25%    1591.250000       4.000000    22.000000     2.500000     0.000000
# 50%    3182.500000       4.000000    27.000000     6.000000     1.000000
# 75%    4773.750000       5.000000    32.000000    16.500000     2.000000
# max    6365.000000       5.000000    42.000000    23.000000     5.500000
#
#          religious         educ   occupation  occupation_husb      affairs
# count  6366.000000  6366.000000  6366.000000      6366.000000  6366.000000
# mean      2.426170    14.209865     3.424128         3.850141     0.705374
# std       0.878369     2.178003     0.942399         1.346435     2.203374
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# Unnamed: 0         6366
# rate_marriage         5
# age                   6
# yrs_married           7
# children              6
# religious             4
# educ                  6
# occupation            6
# occupation_husb       6
# affairs              77
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# # Write your code to make your dataset analysis ready.
# df = pd.get_dummies(df, columns=['occupation', 'occupation_husb'], drop_first=True)
# df['log_affairs'] = np.log1p(df['affairs'])
# df['years_married_ratio'] = df['yrs_married'] / (df['age'] + 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['age', 'yrs_married', 'educ']] = scaler.fit_transform(df[['age', 'yrs_married', 'educ']])

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
(df['affairs'] == 0).mean() * 100
# Out:
# np.float64(67.75054979579014)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.Index Column Removal: Dropped the redundant Unnamed: 0 column, which acted as an arbitrary row counter and would have added random noise to a predictive model.
#
# 2.Target Distribution Check: Evaluated the affairs column and discovered that 67.75% of the entries are exactly 0.
#
# 3.Variable Type Identification: Identified that occupation and occupation_husb are encoded as numeric scales (1 to 6) but are fundamentally categorical variables representing specific job classes

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8, 5))
sns.histplot(df['affairs'], bins=20, kde=True, color='crimson')
plt.title('Distribution of Affairs (Highly Zero-Inflated)', fontsize=14)
plt.xlabel('Affairs (Time spent in extra-marital affairs)', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 5))
sns.barplot(x='rate_marriage', y='affairs', data=df, palette='viridis', errorbar=None)
plt.title('Average Affairs by Marriage Rating', fontsize=14)
plt.xlabel('Marriage Rating (1 = Very Poor, 5 = Very Good)', fontsize=12)
plt.ylabel('Average Affairs', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_765/2911138339.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rate_marriage', y='affairs', data=df, palette='viridis', errorbar=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8, 5))
sns.barplot(x='religious', y='affairs', data=df, palette='crest', errorbar=None)
plt.title('Average Affairs by Religiousness Level', fontsize=14)
plt.xlabel('Religiousness (1 = Not Religious, 4 = Strongly Religious)', fontsize=12)
plt.ylabel('Average Affairs', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_765/4260402654.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='religious', y='affairs', data=df, palette='crest', errorbar=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8, 5))
sns.lineplot(x='yrs_married', y='affairs', data=df, color='darkorange', marker='o', errorbar=None)
plt.title('Trend of Affairs over Years of Marriage', fontsize=14)
plt.xlabel('Years Married', fontsize=12)
plt.ylabel('Average Affairs', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10, 8))
# Compute correlation matrix
corr_matrix = df.corr()

# Generate heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Variables', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6- Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.isnull().sum()
# Out:
# rate_marriage      0
# age                0
# yrs_married        0
# children           0
# religious          0
# educ               0
# occupation         0
# occupation_husb    0
# affairs            0
# dtype: int64

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
df.mean()
# Out:
# rate_marriage      4.109645e+00
# age               -1.071506e-16
# yrs_married        3.571688e-17
# children           1.396874e+00
# religious          2.426170e+00
# educ              -1.741198e-16
# occupation         3.424128e+00
# occupation_husb    3.850141e+00
# affairs            7.053739e-01
# dtype: float64

# %%
df.median()
# Out:
# rate_marriage      4.000000
# age               -0.304185
# yrs_married       -0.413408
# children           1.000000
# religious          2.000000
# educ              -0.096364
# occupation         3.000000
# occupation_husb    4.000000
# affairs            0.000000
# dtype: float64

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

df = pd.get_dummies(df, columns=['occupation', 'occupation_husb'], drop_first=True)
df['log_affairs'] = np.log1p(df['affairs'])
df['years_married_ratio'] = df['yrs_married'] / (df['age'] + 1)
df = df[df['affairs'] > 0]

# %%
df.head()
# Out:
#    rate_marriage       age  yrs_married  children  religious      educ  \
# 0            3.0  0.426025    -0.001295       3.0        3.0  1.281153
# 1            3.0 -0.304185     0.548190       3.0        1.0 -0.096364
# 2            4.0 -1.034396    -0.894207       0.0        1.0  0.821981
# 3            4.0  1.156235     1.028989       4.0        3.0  0.821981
# 4            5.0 -0.304185    -0.001295       1.0        1.0 -0.096364
#
#     affairs  occupation_2.0  occupation_3.0  occupation_4.0  occupation_5.0  \
# 0  0.111111            True           False           False           False
# 1  3.230769           False            True           False           False
# 2  1.400000           False            True           False           False
# 3  0.727273           False           False           False            True
# 4  4.666666           False            True           False           False
#
#    occupation_6.0  occupation_husb_2.0  occupation_husb_3.0  \
# ...

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
x = df.drop(columns=['affairs'])
y = df['affairs']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = Lasso(alpha=0.1)
model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

print('Train mean absolute error :- ',mean_absolute_error(y_train,train_pred))
print('Train mean squared error :- ',mean_squared_error(y_train,train_pred))
print('r2_score:',r2_score(y_train,train_pred))
print()
print('*'*30)
print()
print('Test mean absolute error :-',mean_absolute_error(y_test,test_pred))
print('Test mean squared error :-',mean_squared_error(y_test,test_pred))
print('r2_score:',r2_score(y_test,test_pred))
# Out:
# Train mean absolute error :-  0.8693335443769258
# Train mean squared error :-  3.0907175217161256
# r2_score: 0.7217385951532587
#
# ******************************
#
# Test mean absolute error :- 0.9264264711310042
# Test mean squared error :- 4.767382218218842
# r2_score: 0.673879477697318

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 100]
}

# %%
model = Lasso()

model = GridSearchCV(
    estimator=model,
    param_grid=params,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

model.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]},
#              scoring='r2')

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

print('Train mean absolute error :- ',mean_absolute_error(y_train,train_pred))
print('Train mean squared error :- ',mean_squared_error(y_train,train_pred))

print('r2_score:',r2_score(y_train,train_pred))
print()
print('*'*30)
print()
print('Test mean absolute error :-',mean_absolute_error(y_test,test_pred))
print('Test mean squared error :-',mean_squared_error(y_test,test_pred))

print('r2_score:',r2_score(y_test,test_pred))
# Out:
# Train mean absolute error :-  0.9330368435620783
# Train mean squared error :-  3.016957101128682
# r2_score: 0.7283793438177799
#
# ******************************
#
# Test mean absolute error :- 0.9933208393118178
# Test mean squared error :- 4.607896820617709
# r2_score: 0.6847893353056649

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
model = Ridge(alpha=0.1)
model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

print('Train mean absolute error :- ',mean_absolute_error(y_train,train_pred))
print('Train mean squared error :- ',mean_squared_error(y_train,train_pred))
print('r2_score:',r2_score(y_train,train_pred))
print()
print('*'*30)
print()
print('Test mean absolute error :-',mean_absolute_error(y_test,test_pred))
print('Test mean squared error :-',mean_squared_error(y_test,test_pred))
print('r2_score:',r2_score(y_test,test_pred))
# Out:
# Train mean absolute error :-  0.9437883969726513
# Train mean squared error :-  3.0094249830530133
# r2_score: 0.7290574704154003
#
# ******************************
#
# Test mean absolute error :- 1.0062268610205858
# Test mean squared error :- 4.6141119086472555
# r2_score: 0.6843641821164351

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 100]
}

# %%
model = Ridge()

model = GridSearchCV(
    estimator=model,
    param_grid=params,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

model.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]},
#              scoring='r2')

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error ,mean_absolute_percentage_error

train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

print('Train mean absolute error :- ',mean_absolute_error(y_train,train_pred))
print('Train mean squared error :- ',mean_squared_error(y_train,train_pred))

print('r2_score:',r2_score(y_train,train_pred))
print()
print('*'*30)
print()
print('Test mean absolute error :-',mean_absolute_error(y_test,test_pred))
print('Test mean squared error :-',mean_squared_error(y_test,test_pred))

print('r2_score:',r2_score(y_test,test_pred))
# Out:
# Train mean absolute error :-  0.9232546380035466
# Train mean squared error :-  3.01197566750316
# r2_score: 0.7288278289054817
#
# ******************************
#
# Test mean absolute error :- 0.9859388817407806
# Test mean squared error :- 4.644779178916326
# r2_score: 0.682266337693656

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
